# %%
print("Hola Mundo")
# Out:
# Hola Mundo

# %%
Ejercicios

Ejercicio 1
Respuesta C

¿Que es un programa?
Es un conjunto de instrucciones que indican cómo realizar algun tipo de cálculo o una secuencia de declaraciones o sentencias que han sido diseñados para hacer algo

¿Cuál es la diferencia entre un copilador y un interprete?

Un copilador necesita que le entreguen el programa completo en un fichero en cambio en interprete lee el código fuente de los programas tal y como ha sido escrito por el programador, lo analiza, e interpreta sus instrucciones sobre la marcha.

Ejercicio 4
Respuesta A

¿Qué está mal en este codigo?
Print esta mal escrito y la frase hola mundo debe estar en parentesis

Ejercicio 6
Respuesta A

Ejercicio 7
Respuesta B

Explica cada uno de los conceptos
Unidad central de procesamiento: Es como nuestro cerebro ya que se encarga de recapitular información y coordinar el funcionamiento
Memoria principal: Es como un archivo no guardado de word se utiliza para recapitular información pero sino lo guardas si apagas el equipo se borra
Memoria secundaria:Es como el cerebro y nuestra mente ya que aunque estemos dormidos sigue recapitulando lo wue hicimos en el dia con nuestras horas de sueño
Dispositivos de entrada:Sirven para poder comunicarte o transmitir información como los mensajes
Dispositivos de salida: sirven para transmitirnos información como un anuncio

¿Como puedes corregir un error de sintaxis?
Analizando los errores gramaticales del problema
